# %% [markdown]
# # Deep Learning Tutorial using H2O

# %% [raw]
# Importing files from local repo and anlyzing them for predictive models.

# %%
import os
#os.chdir("C:\Users\srira\Desktop")

# %% [raw]
# [1]Using Deep Learning
#
# H2O’s Deep Learning functionalities include:
#
# -->purely supervised training protocol for regression and classification tasks
# -->fast and memory-efficient Java implementations based on columnar compression and fine-grain Map/Reduce
# -->multi-threaded and distributed parallel computation to be run on either a single node or a multi-node cluster
# -->fully automatic per-neuron adaptive learning rate for fast convergence
# -->optional specification of learning rate, annealing and momentum options
# -->regularization options include L1, L2, dropout, Hogwild! and model averaging to prevent model overfitting
# -->elegant web interface or fully scriptable R API from H2O CRAN package
# -->grid search for hyperparameter optimization and model selection
# -->model checkpointing for reduced run times and model tuning
# -->automatic data pre and post-processing for categorical and numerical data
# -->automatic imputation of missing values
# -->automatic tuning of communication vs computation for best performance
# -->model export in plain java code for deployment in production environments
# -->additional expert parameters for model tuning
# -->deep autoencoders for unsupervised feature learning and anomaly detection capabilities

# %% [raw]
# we have to import data files into H2O before analyzing them.

# %%
from PIL import Image
importfiles = Image.open("importing.png");
importfiles
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=566x741 at 0x856D7F0>

# %%
parsing = Image.open("parsing.png");
parsing
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1411x810 at 0x856D748>

# %% [raw]
# After parsing,we get the following results and the data is ready for building the model.

# %%
parsed = Image.open("parsed1.png");
parsed
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1048x796 at 0x856D978>

# %%
parsed2 = Image.open("parsed2.png");
parsed2
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1059x794 at 0x856D9E8>

# %% [raw]
# After finishing the parsing,we do build the model selecting the algorithm.Here we select Deep learning algorithm.

# %%
deep1 = Image.open("deep build model1.png");
deep1
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1353x820 at 0x8551390>

# %%
deep2 = Image.open("deep build model2.png");
deep2
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=522x826 at 0x856DB38>

# %%
output = Image.open("output.png");
output
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=717x630 at 0x856D9B0>

# %%
prediction = Image.open("prediction.png");
prediction
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=742x556 at 0x856D4A8>

# %% [raw]
# citations:
#
# [1]h2oai. “h2oai/h2o-3.” GitHub, github.com/h2oai/h2o-3/blob/master/h2o-docs/src/product/tutorials/dl/dl.md.

# %% [raw]
# Please find the below link for H2O flow:
# URL:
# http://localhost:54321/flow/index.html#
# file:
# pollution.flow

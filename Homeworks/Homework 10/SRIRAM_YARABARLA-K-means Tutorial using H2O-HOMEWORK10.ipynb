# %% [markdown]
# # K-Means Tutorial using H2O

# %% [raw]
# Importing files from local repo and anlyzing them for predictive models.

# %%
import os
#os.chdir("C:\Users\srira\Desktop")

# %% [raw]
# [1]K-means algorithm has a "k-modes" function that allows you to use mixed categorical and real-valued data. By using dissimilarity measures to handle categoricals, replacing cluster means with cluster modes, and using a frequency-based method to update modes in the clustering process to minimize the clustering costs, the k-modes algorithm is scalable in both the number of clusters and the number of records. The k-modes method is used anytime categorical data is present.

# %% [raw]
# we have to import data files into H2O before analyzing them.

# %%
from PIL import Image
importfiles = Image.open("importing_kmeans.png");
importfiles
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=566x741 at 0x83B5B70>

# %%
parsing = Image.open("parsing_kmeans.png");
parsing
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1411x810 at 0x8440160>

# %% [raw]
# After parsing,we get the following results and the data is ready for building the model.

# %%
parsed = Image.open("parsed1_kmeans.png");
parsed
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1048x796 at 0x856D978>

# %%
parsed2 = Image.open("parsed2_kmeans.png");
parsed2
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1059x794 at 0x856D9E8>

# %% [raw]
# After finishing the parsing,we do build the model selecting the algorithm.Here we select Deep learning algorithm.

# %%
kmeansbuild = Image.open("k means build.png");
kmeansbuild
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1238x772 at 0x85895C0>

# %%
kmeansmodel = Image.open("k means model.png");
kmeansmodel
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=746x804 at 0x85896D8>

# %%
kmeansoutput = Image.open("k means output1.png");
kmeansoutput
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=449x777 at 0x8589748>

# %%
Kmeansprediction = Image.open("K means prediction.png");
Kmeansprediction
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=695x758 at 0x85897F0>

# %% [raw]
# citations:
#
# [1]h2oai. “h2oai/h2o-3.” GitHub, github.com/h2oai/h2o-3/blob/master/h2o-docs/src/product/tutorials/kmeans/kmeans.md.

# %% [raw]
# Please find the below link for H2O flow:
# URL:
# http://localhost:54321/flow/index.html#
# file:
# pollution.flow

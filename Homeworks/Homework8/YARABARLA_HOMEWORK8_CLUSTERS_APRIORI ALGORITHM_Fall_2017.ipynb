# %%
#using pandas
import os
import pandas as pd
import numpy as np
from numpy import *

# %%
# !type ATT.csv
# Out:
# Region,DataRequestType,,
# OHIO,WIRELESS,,
# OHIO,WIRELESS,,
# OHIO,WIRELESS,,
# OHIO,WIRELESS,,
# OHIO,WIRELESS,,
# OHIO,WIRELESS,,
# OHIO,WIRELESS,,
# OHIO,WIRELESS,,
# OHIO,WIRELESS,,
# OHIO,WIRELESS,,
# OHIO,WIRELESS,,
# OHIO,WIRELESS,,
# OHIO,WIRELESS,,
# OHIO,WIRELESS,,
# OHIO,WIRELESS,,
# OHIO,WIRELESS,,
# OHIO,WIRELESS,,
# OHIO,WIRELESS,,
# INDIANA,WIRELESS,,
# INDIANA,WIRELESS,,
# INDIANA,WIRELESS,,
# INDIANA,WIRELESS,,
# INDIANA,WIRELESS,,
# INDIANA,WIRELESS,,
# INDIANA,WIRELESS,,
# INDIANA,WIRELESS,,
# INDIANA,WIRELESS,,
# INDIANA,WIRELESS,,
# INDIANA,WIRELESS,,
# INDIANA,WIRELESS,,
# INDIANA,WIRELESS,,
# INDIANA,WIRELESS,,
# NEWYORK,DirecTV,,
# NEWYORK,DirecTV,,
# NEWYORK,DirecTV,,
# NEWYORK,DirecTV,,
# ALABAMA,WIRELESS,,
# ALABAMA,WIRELESS,,
# NEWYORK,U-VERSE,,
# NEWYORK,U-VERSE,,
# NEWYORK,U-VERSE,,
# TEXAS,WIRELINES,,
# TEXAS,WIRELINES,,
# TEXAS,WIRELINES,,
# NEWYORK,U-VERSE,,
# CALIFORNIA,WLL,,
# CALIFORNIA,WLL,,
# CALIFORNIA,WLL,,
# ALABAMA,WIRELESS,,
# ALABAMA,WIRELESS,,
# ALABAMA,WIRELESS,,
# NEWYORK,CB(SynergyDTV+3rdPartyWireline),,
# NEWYORK,CB(SynergyDTV+3rdPartyWireline),,
# NEWYORK,CB(SynergyDTV+3rdPartyWireline),,
# NEWYORK,Unified(Uverse+Wireless+DTV),,
# TEXAS,WIRELINES,,
# TEXAS,WIRELINES,,
# TEXAS,WIRELINES,,
# TEXAS,WIRELINES,,
# ALABAMA,WIRELESS,,
# ALABAMA,WIRELESS,,
# ALABAMA,WIRELESS,,
# TEXAS,WIRELINES,,
# NEWYORK,U-VERSE,,
# TEXAS,WIRELINES,,
# NEWYORK,Unified(Uverse+Wireless+DTV),,
# PENSELVANIYA,CB-WIRELINE,,
# TEXAS,WIRELINES,,
# NEWYORK,U-VERSE,,
# ALABAMA,WIRELESS,,
# ALABAMA,WIRELESS,,
# ALABAMA,WIRELESS,,
# ALABAMA,WIRELESS,,
# NEWYORK,U-VERSE,,
# TEXAS,WIRELINES,,
# NEWYORK,U-VERSE,,
# PENSELVANIYA,WIRELINES,,
# PENSELVANIYA,WIRELINES,,
# ALABAMA,WIRELESS,,
# NEWYORK,U-VERSE,,
# NEWYORK,DirecTV,,
# PENSELVANIYA,WIRELINES,,
# NEWYORK,OPENPORTAL,,
# PENSELVANIYA,OPENPORTAL,,
# MISSOURI,OPENPORTAL,,
# NEWYORK,Unified(Uverse+DTV),,
# PENSELVANIYA,Unified(Uverse+DTV),,
# NEWYORK,DirecTV,,
# NEWYORK,DirecTV,,
# NEWYORK,U-VERSE,,
# NEWYORK,U-VERSE,,
# PENSELVANIYA,WIRELINES,,
# PENSELVANIYA,WIRELINES,,
# PENSELVANIYA,WIRELINES,,
# PENSELVANIYA,WIRELINES,,
# PENSELVANIYA,WIRELINES,,
# PENSELVANIYA,WIRELINES,,
# PENSELVANIYA,WIRELINES,,
# PENSELVANIYA,WIRELINES,,
# PENSELVANIYA,WIRELINES,,
# PENSELVANIYA,WIRELINES,,
# PENSELVANIYA,WIRELINES,,
# PENSELVANIYA,WIRELINES,,
# NEWYORK,DirecTV,,
# NEWYORK,DirecTV,,
# NEWYORK,DirecTV,,
# NEWYORK,DirecTV,,
# NEWYORK,DirecTV,,
# NEWYORK,DirecTV,,
# NEWYORK,DirecTV,,
# NEWYORK,DirecTV,,
# NEWYORK,DirecTV,,
# ALABAMA,WIRELESS,,
# ALABAMA,WIRELESS,,
# ALABAMA,WIRELESS,,
# ALABAMA,WIRELESS,,
# ALABAMA,WIRELESS,,
# ALABAMA,WIRELESS,,
# ALABAMA,WIRELESS,,
# NEWYORK,U-VERSE,,
# NEWYORK,U-VERSE,,
# OHIO,Unified(Uverse+DTV),,
# NEWYORK,U-VERSE,,
# NEWYORK,DirecTV,,
# TEXAS,Unified(Uverse+DTV),,
# TEXAS,Unified(Wireless+DTV),,
# NEWYORK,Unified(Uverse+Wireless+DTV),,
# NEWYORK,Unified(Uverse+Wireless+DTV),,
# ALABAMA,WIRELESS,,
# ALABAMA,WIRELESS,,
# MISSOURI,WIRELESS,,
# MISSOURI,WIRELESS,,
# MISSOURI,WIRELESS,,
# MISSOURI,WIRELESS,,
# MISSOURI,WIRELESS,,
# MISSOURI,WIRELESS,,
# MISSOURI,WIRELESS,,
# MISSOURI,WIRELESS,,
# MISSOURI,WIRELESS,,
# MISSOURI,WIRELESS,,
# MISSOURI,WIRELESS,,
# MISSOURI,WIRELESS,,
# MISSOURI,WIRELESS,,
# MISSOURI,WIRELESS,,
# MISSOURI,WIRELESS,,
# NEWYORK,Unified(Uverse+DTV),,
# NEWYORK,DirecTV,,
# PENSELVANIYA,WIRELINES,,
# PENSELVANIYA,DirecTV,,
# PENSELVANIYA,DirecTV,,
# PENSELVANIYA,WIRELINES,,
# PENSELVANIYA,WIRELINES,,
# PENSELVANIYA,WIRELINES,,
# PENSELVANIYA,WIRELINES,,
# MISSOURI,CB-WIRELINE,,
# OHIO,CB-WIRELINE,,
# NEWYORK,U-VERSE,,
# NEWYORK,U-VERSE,,
# NEWYORK,U-VERSE,,
# NEWYORK,U-VERSE,,
# OHIO,U-VERSE,,
# OHIO,U-VERSE,,
# OHIO,U-VERSE,,
# OHIO,U-VERSE,,
# PENSELVANIYA,DirecTV,,
# PENSELVANIYA,DirecTV,,
# PENSELVANIYA,DirecTV,,
# MISSOURI,WIRELESS,,
# MISSOURI,WIRELESS,,
# MISSOURI,WIRELESS,,
# MISSOURI,WIRELESS,,
# MISSOURI,WIRELESS,,
# MISSOURI,WIRELESS,,
# OHIO,U-VERSE,,
# PENSELVANIYA,WIRELINES,,
# MISSOURI,WIRELESS,,
# OHIO,U-VERSE,,
# PENSELVANIYA,WIRELINES,,
# OHIO,CB-U-VERSE,,
# OHIO,CB-WIRELINE,,
# OHIO,U-VERSE,,
# OHIO,U-VERSE,,
# MISSOURI,WIRELESS,,
# OHIO,U-VERSE,,
# TEXAS,WIRELESS,,
# OHIO,U-VERSE,,
# NEWYORK,WIRELINES,,
# TEXAS,WIRELESS,,
# TEXAS,WIRELESS,,
# TEXAS,WIRELESS,,
# TEXAS,WIRELESS,,
# TEXAS,WIRELESS,,
# PENSELVANIYA,DirecTV,,
# NEWYORK,Unified(WLL+Wireless),,
# TEXAS,Unified(Wireless+DTV),,
# PENSELVANIYA,DirecTV,,
# PENSELVANIYA,DirecTV,,
# PENSELVANIYA,Unified(WLL+DTV),,
# NEWYORK,Unified(WLL+Wireless+DTV),,
# CALIFORNIA,WLL,,
# CALIFORNIA,WLL,,
# OHIO,U-VERSE,,
# OHIO,U-VERSE,,
# OHIO,U-VERSE,,
# NEWYORK,WIRELINES,,
# OHIO,CB-U-VERSE,,
# OHIO,CB-WIRELINE,,
# OHIO,U-VERSE,,
# OHIO,U-VERSE,,
# NEWYORK,WIRELINES,,
# GEORGIA,U-VERSE,,
# NEWYORK,WIRELINES,,
# GEORGIA,U-VERSE,,
# GEORGIA,U-VERSE,,
# OHIO,CB-U-VERSE,,
# GEORGIA,U-VERSE,,
# TEXAS,WIRELESS,,
# TEXAS,WIRELESS,,
# TEXAS,WIRELESS,,
# TEXAS,WIRELESS,,
# TEXAS,WIRELESS,,
# TEXAS,WIRELESS,,
# TEXAS,WIRELESS,,
# TEXAS,WIRELESS,,
# TEXAS,WIRELESS,,
# TEXAS,WIRELESS,,
# TEXAS,WIRELESS,,
# TEXAS,WIRELESS,,
# TEXAS,WIRELESS,,
# TEXAS,WIRELESS,,
# TEXAS,WIRELESS,,
# TEXAS,WIRELESS,,
# TEXAS,WIRELESS,,
# TEXAS,WIRELESS,,
# TEXAS,WIRELESS,,
# TEXAS,WIRELESS,,
# TEXAS,WIRELESS,,
# TEXAS,WIRELESS,,
# TEXAS,WIRELESS,,
# TEXAS,WIRELESS,,
# TEXAS,WIRELESS,,
# TEXAS,WIRELESS,,
# TEXAS,WIRELESS,,
# TEXAS,WIRELESS,,
# TEXAS,WIRELESS,,
# TEXAS,WIRELESS,,
# TEXAS,WIRELESS,,
# NEWYORK,WIRELESS,,
# NEWYORK,WIRELESS,,
# NEWYORK,WIRELESS,,
# NEWYORK,WIRELESS,,
# NEWYORK,WIRELESS,,
# NEWYORK,WIRELESS,,
# NEWYORK,WIRELESS,,
# NEWYORK,WIRELESS,,
# NEWYORK,WIRELESS,,
# NEWYORK,WIRELESS,,
# NEWYORK,WIRELESS,,
# NEWYORK,WIRELESS,,
# NEWYORK,WIRELESS,,
# NEWYORK,WIRELESS,,
# NEWYORK,WIRELESS,,
# PENSELVANIYA,CB-U-VERSE,,
# MISSOURI,Unified(Uverse+Wireless+DTV),,
# NEWYORK,WIRELESS,,
# GEORGIA,U-VERSE,,
# PENSELVANIYA,DirecTV,,
# NEWYORK,WIRELINES,,
# PENSELVANIYA,CB-U-VERSE,,
# CALIFORNIA,WLL,,
# TEXAS,Unified(Wireless+DTV),,
# GEORGIA,U-VERSE,,
# MISSOURI,Unified(Uverse+Wireless+DTV),,
# NEWYORK,WIRELESS,,
# NEWYORK,WIRELESS,,
# MISSOURI,DirecTV,,
# MISSOURI,DirecTV,,
# NEWYORK,WIRELINES,,
# NEWYORK,WIRELINES,,
# NEWYORK,WIRELINES,,
# NEWYORK,WIRELINES,,
# MISSOURI,Unified(Uverse+Wireless+DTV),,
# GEORGIA,U-VERSE,,
# GEORGIA,U-VERSE,,
# GEORGIA,U-VERSE,,
# GEORGIA,U-VERSE,,
# CALIFORNIA,WLL,,
# TEXAS,Unified(WLL+Wireless),,
# NEWYORK,WIRELESS,,
# GEORGIA,U-VERSE,,
# CALIFORNIA,WLL,,
# MISSOURI,Unified(Uverse+Wireless+DTV),,
# NEWYORK,Unified(Wireless+DTV),,
# NEWYORK,Unified(Uverse+Wireless),,
# NEWYORK,WLL,,
# NEWYORK,WLL,,
# GEORGIA,U-VERSE,,
# MISSOURI,Unified(Uverse+Wireless+DTV),,
# PENSELVANIYA,Unified(Uverse+Wireless+DTV),,
# NEWYORK,WIRELINES,,
# NEWYORK,WIRELINES,,
# GEORGIA,U-VERSE,,
# GEORGIA,U-VERSE,,
# NEWYORK,WIRELINES,,
# NEWYORK,WLL,,
# GEORGIA,U-VERSE,,
# GEORGIA,U-VERSE,,
# PENSELVANIYA,CB-U-VERSE,,
# PENSELVANIYA,CB(Wireline+SynergyDTV),,
# NEWYORK,CB(SynergyDTV+3rdPartyWireline),,
# MISSOURI,CB(SynergyDTV+3rdPartyWireline),,
# OHIO,CB(Wireline+SynergyDTV),,
# NEWYORK,WIRELESS,,
# NEWYORK,WIRELESS,,
# NEWYORK,WIRELESS,,
# NEWYORK,WIRELESS,,
# NEWYORK,WIRELESS,,
# NEWYORK,WIRELESS,,
# NEWYORK,WIRELESS,,
# NEWYORK,WIRELESS,,
# NEWYORK,WIRELESS,,
# NEWYORK,WIRELESS,,
# NEWYORK,WIRELESS,,
# NEWYORK,WIRELESS,,
# NEWYORK,WIRELESS,,
# NEWYORK,WIRELESS,,
# NEWYORK,WIRELESS,,
# NEWYORK,WIRELINES,,
# NEWYORK,WIRELINES,,
# NEWYORK,WIRELINES,,
# NEWYORK,WIRELINES,,
# NEWYORK,WIRELINES,,
# GEORGIA,U-VERSE,,
# GEORGIA,U-VERSE,,
# NEWYORK,WIRELINES,,
# ALABAMA,U-VERSE,,
# ALABAMA,U-VERSE,,
# NEWYORK,WIRELINES,,
# ALABAMA,U-VERSE,,
# ALABAMA,U-VERSE,,
# ALABAMA,U-VERSE,,
# ALABAMA,U-VERSE,,
# ALABAMA,U-VERSE,,
# NEWYORK,WIRELESS,,
# NEWYORK,WIRELESS,,
# NEWYORK,WIRELESS,,
# ALABAMA,U-VERSE,,
# NEWYORK,WIRELINES,,
# NEWYORK,WIRELINES,,
# MISSOURI,DirecTV,,
# MISSOURI,DirecTV,,
# MISSOURI,DirecTV,,
# MISSOURI,Unified(Uverse+DTV),,
# PENSELVANIYA,Unified(Uverse+Wireless+DTV),,
# NEWYORK,WLL,,
# ALABAMA,U-VERSE,,
# PENSELVANIYA,WLL,,
# ALABAMA,U-VERSE,,
# PENSELVANIYA,CB-U-VERSE,,
# OHIO,CB-WIRELINE,,
# ALABAMA,U-VERSE,,
# PENSELVANIYA,WLL,,
# NEWYORK,WIRELINES,,
# NEWYORK,WIRELINES,,
# ALABAMA,U-VERSE,,
# PENSELVANIYA,WLL,,
# ALABAMA,U-VERSE,,
# ALABAMA,U-VERSE,,
# ALABAMA,U-VERSE,,
# PENSELVANIYA,WLL,,
# NEWYORK,WIRELINES,,
# ALABAMA,U-VERSE,,
# ALABAMA,U-VERSE,,
# ALABAMA,U-VERSE,,
# ALABAMA,U-VERSE,,
# NEWYORK,WIRELESS,,
# NEWYORK,WIRELESS,,
# NEWYORK,WIRELESS,,
# NEWYORK,WIRELESS,,
# NEWYORK,WIRELESS,,
# NEWYORK,WIRELESS,,
# NEWYORK,WIRELESS,,
# NEWYORK,WIRELESS,,
# ALABAMA,U-VERSE,,
# NEWYORK,WIRELESS,,
# NEWYORK,WIRELESS,,
# NEWYORK,WIRELESS,,
# NEWYORK,WIRELINES,,
# NEWYORK,WIRELINES,,
# NEWYORK,WIRELESS,,
# NEWYORK,WIRELESS,,
# NEWYORK,WIRELESS,,
# MISSOURI,DirecTV,,
# MISSOURI,DirecTV,,
# TEXAS,DirecTV,,
# TEXAS,DirecTV,,
# OHIO,Unified(Wireless+DTV),,
# PENSELVANIYA,Unified(Uverse+Wireless+DTV),,
# TEXAS,DirecTV,,
# TEXAS,DirecTV,,
# TEXAS,DirecTV,,
# TEXAS,DirecTV,,
# TEXAS,DirecTV,,
# TEXAS,DirecTV,,
# TEXAS,DirecTV,,
# TEXAS,DirecTV,,
# ALABAMA,DirecTV,,
# ALABAMA,DirecTV,,
# ALABAMA,DirecTV,,
# ALABAMA,DirecTV,,
# ALABAMA,DirecTV,,
# ALABAMA,DirecTV,,
# ALABAMA,DirecTV,,
# ALABAMA,DirecTV,,
# ALABAMA,DirecTV,,
# NEWYORK,WIRELESS,,
# ALABAMA,DirecTV,,
# NEWYORK,WIRELESS,,
# ALABAMA,DirecTV,,
# NEWYORK,WIRELESS,,
# ALABAMA,DirecTV,,
# NEWYORK,WIRELESS,,
# ALABAMA,DirecTV,,
# NEWYORK,WIRELESS,,
# ALABAMA,DirecTV,,
# NEWYORK,DigitalLife,,
# ALABAMA,DirecTV,,
# MISSOURI,DigitalLife,,
# ALABAMA,DirecTV,,
# ALABAMA,DirecTV,,
# ALABAMA,DirecTV,,
# MISSOURI,DirecTV,,
# MISSOURI,DirecTV,,
# MISSOURI,DirecTV,,
# MISSOURI,DirecTV,,
# MISSOURI,DirecTV,,
# MISSOURI,DirecTV,,
# MISSOURI,DirecTV,,
# MISSOURI,DirecTV,,
# MISSOURI,DirecTV,,
# MISSOURI,DirecTV,,
# MISSOURI,DirecTV,,
# MISSOURI,DirecTV,,
# MISSOURI,DirecTV,,
# MISSOURI,DirecTV,,
# MISSOURI,DirecTV,,
# MISSOURI,DirecTV,,
# MISSOURI,DirecTV,,
# MISSOURI,DirecTV,,
# MISSOURI,DirecTV,,
# MISSOURI,DirecTV,,
# NEWYORK,DirecTV,,
# NEWYORK,DirecTV,,
# NEWYORK,DirecTV,,
# NEWYORK,DirecTV,,
# NEWYORK,DirecTV,,
# NEWYORK,DirecTV,,
# NEWYORK,DirecTV,,
# NEWYORK,DirecTV,,
# NEWYORK,DirecTV,,
# NEWYORK,DirecTV,,

# %%
data = pd.read_table("ATT.csv", sep=',', header=None)
data
# Out:
#             0                1   2   3
# 0      Region  DataRequestType NaN NaN
# 1        OHIO         WIRELESS NaN NaN
# 2        OHIO         WIRELESS NaN NaN
# 3        OHIO         WIRELESS NaN NaN
# 4        OHIO         WIRELESS NaN NaN
# 5        OHIO         WIRELESS NaN NaN
# 6        OHIO         WIRELESS NaN NaN
# 7        OHIO         WIRELESS NaN NaN
# 8        OHIO         WIRELESS NaN NaN
# 9        OHIO         WIRELESS NaN NaN
# 10       OHIO         WIRELESS NaN NaN
# 11       OHIO         WIRELESS NaN NaN
# 12       OHIO         WIRELESS NaN NaN
# 13       OHIO         WIRELESS NaN NaN
# 14       OHIO         WIRELESS NaN NaN
# 15       OHIO         WIRELESS NaN NaN
# 16       OHIO         WIRELESS NaN NaN
# 17       OHIO         WIRELESS NaN NaN
# 18       OHIO         WIRELESS NaN NaN
# 19    INDIANA         WIRELESS NaN NaN
# 20    INDIANA         WIRELESS NaN NaN
# 21    INDIANA         WIRELESS NaN NaN
# 22    INDIANA         WIRELESS NaN NaN
# 23    INDIANA         WIRELESS NaN NaN
# 24    INDIANA         WIRELESS NaN NaN
# 25    INDIANA         WIRELESS NaN NaN
# 26    INDIANA         WIRELESS NaN NaN
# 27    INDIANA         WIRELESS NaN NaN
# 28    INDIANA         WIRELESS NaN NaN
# 29    INDIANA         WIRELESS NaN NaN
# ..        ...              ...  ..  ..
# 432  MISSOURI          DirecTV NaN NaN
# 433  MISSOURI          DirecTV NaN NaN
# 434  MISSOURI          DirecTV NaN NaN
# 435  MISSOURI          DirecTV NaN NaN
# 436  MISSOURI          DirecTV NaN NaN
# 437  MISSOURI          DirecTV NaN NaN
# 438  MISSOURI          DirecTV NaN NaN
# 439  MISSOURI          DirecTV NaN NaN
# 440  MISSOURI          DirecTV NaN NaN
# 441  MISSOURI          DirecTV NaN NaN
# 442  MISSOURI          DirecTV NaN NaN
# 443  MISSOURI          DirecTV NaN NaN
# 444  MISSOURI          DirecTV NaN NaN
# 445  MISSOURI          DirecTV NaN NaN
# 446  MISSOURI          DirecTV NaN NaN
# 447  MISSOURI          DirecTV NaN NaN
# 448  MISSOURI          DirecTV NaN NaN
# 449  MISSOURI          DirecTV NaN NaN
# 450  MISSOURI          DirecTV NaN NaN
# 451  MISSOURI          DirecTV NaN NaN
# 452   NEWYORK          DirecTV NaN NaN
# 453   NEWYORK          DirecTV NaN NaN
# 454   NEWYORK          DirecTV NaN NaN
# 455   NEWYORK          DirecTV NaN NaN
# 456   NEWYORK          DirecTV NaN NaN
# 457   NEWYORK          DirecTV NaN NaN
# 458   NEWYORK          DirecTV NaN NaN
# 459   NEWYORK          DirecTV NaN NaN
# 460   NEWYORK          DirecTV NaN NaN
# 461   NEWYORK          DirecTV NaN NaN
#
# [462 rows x 4 columns]

# %%
data = genfromtxt('ATT.csv',skip_header=1, delimiter=',', dtype=None,usecols=arange(0,2))

# %%
x=data

# %%
a=np.array(x)
a
# Out:
# array([['OHIO', 'WIRELESS'],
#        ['OHIO', 'WIRELESS'],
#        ['OHIO', 'WIRELESS'],
#        ['OHIO', 'WIRELESS'],
#        ['OHIO', 'WIRELESS'],
#        ['OHIO', 'WIRELESS'],
#        ['OHIO', 'WIRELESS'],
#        ['OHIO', 'WIRELESS'],
#        ['OHIO', 'WIRELESS'],
#        ['OHIO', 'WIRELESS'],
#        ['OHIO', 'WIRELESS'],
#        ['OHIO', 'WIRELESS'],
#        ['OHIO', 'WIRELESS'],
#        ['OHIO', 'WIRELESS'],
#        ['OHIO', 'WIRELESS'],
#        ['OHIO', 'WIRELESS'],
#        ['OHIO', 'WIRELESS'],
#        ['OHIO', 'WIRELESS'],
#        ['INDIANA', 'WIRELESS'],
#        ['INDIANA', 'WIRELESS'],
#        ['INDIANA', 'WIRELESS'],
#        ['INDIANA', 'WIRELESS'],
#        ['INDIANA', 'WIRELESS'],
#        ['INDIANA', 'WIRELESS'],
#        ['INDIANA', 'WIRELESS'],
#        ['INDIANA', 'WIRELESS'],
#        ['INDIANA', 'WIRELESS'],
#        ['INDIANA', 'WIRELESS'],
#        ['INDIANA', 'WIRELESS'],
#        ['INDIANA', 'WIRELESS'],
#        ['INDIANA', 'WIRELESS'],
#        ['INDIANA', 'WIRELESS'],
#        ['TEXAS', 'DirecTV'],
#        ['NEWYORK', 'DirecTV'],
#        ['NEWYORK', 'WIRELINES'],
#        ['NEWYORK', 'DirecTV'],
#        ['ALABAMA', 'WIRELESS'],
#        ['ALABAMA', 'WIRELESS'],
#        ['NEWYORK', 'U-VERSE'],
#        ['NEWYORK', 'Unified(WLL+Wireless+DTV)'],
#        ['PENSELVANIYA', 'U-VERSE'],
#        ['TEXAS', 'WIRELINES'],
#        ['TEXAS', 'WIRELINES'],
#        ['TEXAS', 'WIRELINES'],
#        ['NEWYORK', 'U-VERSE'],
#        ['CALIFORNIA', 'WLL'],
#        ['CALIFORNIA', 'WLL'],
#        ['CALIFORNIA', 'WLL'],
#        ['ALABAMA', 'WIRELESS'],
#        ['ALABAMA', 'WIRELESS'],
#        ['ALABAMA', 'WIRELESS'],
#        ['NEWYORK', 'CB(SynergyDTV+3rdPartyWireline)'],
#        ['NEWYORK', 'CB(SynergyDTV+3rdPartyWireline)'],
#        ['NEWYORK', 'CB(SynergyDTV+3rdPartyWireline)'],
#        ['NEWYORK', 'Unified(Uverse+Wireless+DTV)'],
#        ['TEXAS', 'WIRELINES'],
#        ['TEXAS', 'WIRELINES'],
#        ['TEXAS', 'WIRELINES'],
#        ['TEXAS', 'WIRELINES'],
#        ['ALABAMA', 'WIRELESS'],
#        ['ALABAMA', 'WIRELESS'],
#        ['ALABAMA', 'WIRELESS'],
#        ['TEXAS', 'WIRELINES'],
#        ['NEWYORK', 'WIRELESS'],
#        ['TEXAS', 'WIRELESS'],
#        ['NEWYORK', 'Unified(Uverse+Wireless+DTV)'],
#        ['PENSELVANIYA', 'CB-WIRELINE'],
#        ['TEXAS', 'WIRELINES'],
#        ['MISSOURI', 'WIRELESS'],
#        ['ALABAMA', 'WIRELESS'],
#        ['ALABAMA', 'WIRELESS'],
#        ['ALABAMA', 'WIRELESS'],
#        ['ALABAMA', 'WIRELESS'],
#        ['NEWYORK', 'U-VERSE'],
#        ['TEXAS', 'WIRELINES'],
#        ['NEWYORK', 'U-VERSE'],
#        ['PENSELVANIYA', 'WIRELINES'],
#        ['PENSELVANIYA', 'WIRELINES'],
#        ['ALABAMA', 'WIRELESS'],
#        ['NEWYORK', 'U-VERSE'],
#        ['NEWYORK', 'DirecTV'],
#        ['PENSELVANIYA', 'WIRELINES'],
#        ['NEWYORK', 'OPENPORTAL'],
#        ['PENSELVANIYA', 'OPENPORTAL'],
#        ['MISSOURI', 'OPENPORTAL'],
#        ['NEWYORK', 'Unified(Uverse+DTV)'],
#        ['PENSELVANIYA', 'Unified(Uverse+DTV)'],
#        ['NEWYORK', 'DirecTV'],
#        ['NEWYORK', 'DirecTV'],
#        ['NEWYORK', 'U-VERSE'],
#        ['NEWYORK', 'U-VERSE'],
#        ['PENSELVANIYA', 'WIRELINES'],
#        ['PENSELVANIYA', 'WIRELINES'],
#        ['PENSELVANIYA', 'WIRELINES'],
#        ['PENSELVANIYA', 'WIRELINES'],
#        ['PENSELVANIYA', 'WIRELINES'],
#        ['PENSELVANIYA', 'WIRELINES'],
#        ['PENSELVANIYA', 'WIRELINES'],
#        ['PENSELVANIYA', 'WIRELINES'],
#        ['PENSELVANIYA', 'WIRELINES'],
#        ['PENSELVANIYA', 'WIRELINES'],
#        ['PENSELVANIYA', 'WIRELINES'],
#        ['PENSELVANIYA', 'WIRELINES'],
#        ['NEWYORK', 'DirecTV'],
#        ['NEWYORK', 'DirecTV'],
#        ['NEWYORK', 'DirecTV'],
#        ['NEWYORK', 'DirecTV'],
#        ['NEWYORK', 'DirecTV'],
#        ['NEWYORK', 'DirecTV'],
#        ['NEWYORK', 'DirecTV'],
#        ['NEWYORK', 'DirecTV'],
#        ['NEWYORK', 'DirecTV'],
#        ['ALABAMA', 'WIRELESS'],
#        ['ALABAMA', 'WIRELESS'],
#        ['ALABAMA', 'WIRELESS'],
#        ['ALABAMA', 'WIRELESS'],
#        ['ALABAMA', 'WIRELESS'],
#        ['ALABAMA', 'WIRELESS'],
#        ['ALABAMA', 'WIRELESS'],
#        ['NEWYORK', 'U-VERSE'],
#        ['NEWYORK', 'U-VERSE'],
#        ['OHIO', 'Unified(Uverse+DTV)'],
#        ['NEWYORK', 'U-VERSE'],
#        ['NEWYORK', 'DirecTV'],
#        ['TEXAS', 'Unified(Uverse+DTV)'],
#        ['TEXAS', 'Unified(Wireless+DTV)'],
#        ['NEWYORK', 'Unified(Uverse+Wireless+DTV)'],
#        ['NEWYORK', 'Unified(Uverse+Wireless+DTV)'],
#        ['ALABAMA', 'WIRELESS'],
#        ['ALABAMA', 'WIRELESS'],
#        ['MISSOURI', 'WIRELESS'],
#        ['MISSOURI', 'WIRELESS'],
#        ['MISSOURI', 'WIRELESS'],
#        ['MISSOURI', 'WIRELESS'],
#        ['MISSOURI', 'WIRELESS'],
#        ['MISSOURI', 'WIRELESS'],
#        ['MISSOURI', 'WIRELESS'],
#        ['MISSOURI', 'WIRELESS'],
#        ['MISSOURI', 'WIRELESS'],
#        ['MISSOURI', 'WIRELESS'],
#        ['MISSOURI', 'WIRELESS'],
#        ['MISSOURI', 'WIRELESS'],
#        ['MISSOURI', 'WIRELESS'],
#        ['MISSOURI', 'WIRELESS'],
#        ['MISSOURI', 'WIRELESS'],
#        ['NEWYORK', 'Unified(Uverse+DTV)'],
#        ['NEWYORK', 'DirecTV'],
#        ['PENSELVANIYA', 'WIRELINES'],
#        ['PENSELVANIYA', 'DirecTV'],
#        ['PENSELVANIYA', 'DirecTV'],
#        ['PENSELVANIYA', 'WIRELINES'],
#        ['PENSELVANIYA', 'WIRELINES'],
#        ['PENSELVANIYA', 'WIRELINES'],
#        ['PENSELVANIYA', 'WIRELINES'],
#        ['MISSOURI', 'CB-WIRELINE'],
#        ['OHIO', 'CB-WIRELINE'],
#        ['NEWYORK', 'U-VERSE'],
#        ['NEWYORK', 'U-VERSE'],
#        ['NEWYORK', 'U-VERSE'],
#        ['NEWYORK', 'U-VERSE'],
#        ['OHIO', 'U-VERSE'],
#        ['OHIO', 'U-VERSE'],
#        ['OHIO', 'U-VERSE'],
#        ['OHIO', 'U-VERSE'],
#        ['PENSELVANIYA', 'DirecTV'],
#        ['PENSELVANIYA', 'DirecTV'],
#        ['PENSELVANIYA', 'DirecTV'],
#        ['MISSOURI', 'WIRELESS'],
#        ['MISSOURI', 'WIRELESS'],
#        ['MISSOURI', 'WIRELESS'],
#        ['MISSOURI', 'WIRELESS'],
#        ['MISSOURI', 'WIRELESS'],
#        ['MISSOURI', 'WIRELESS'],
#        ['OHIO', 'U-VERSE'],
#        ['PENSELVANIYA', 'WIRELINES'],
#        ['MISSOURI', 'WIRELESS'],
#        ['OHIO', 'U-VERSE'],
#        ['PENSELVANIYA', 'WIRELINES'],
#        ['OHIO', 'CB-U-VERSE'],
#        ['OHIO', 'CB-WIRELINE'],
#        ['OHIO', 'U-VERSE'],
#        ['OHIO', 'U-VERSE'],
#        ['MISSOURI', 'WIRELESS'],
#        ['OHIO', 'U-VERSE'],
#        ['TEXAS', 'WIRELESS'],
#        ['OHIO', 'U-VERSE'],
#        ['NEWYORK', 'WIRELINES'],
#        ['TEXAS', 'WIRELESS'],
#        ['TEXAS', 'WIRELESS'],
#        ['TEXAS', 'WIRELESS'],
#        ['TEXAS', 'WIRELESS'],
#        ['TEXAS', 'WIRELESS'],
#        ['PENSELVANIYA', 'DirecTV'],
#        ['NEWYORK', 'Unified(WLL+Wireless)'],
#        ['TEXAS', 'Unified(Wireless+DTV)'],
#        ['PENSELVANIYA', 'DirecTV'],
#        ['PENSELVANIYA', 'DirecTV'],
#        ['PENSELVANIYA', 'Unified(WLL+DTV)'],
#        ['NEWYORK', 'Unified(WLL+Wireless+DTV)'],
#        ['CALIFORNIA', 'WLL'],
#        ['CALIFORNIA', 'WLL'],
#        ['OHIO', 'U-VERSE'],
#        ['OHIO', 'U-VERSE'],
#        ['OHIO', 'U-VERSE'],
#        ['NEWYORK', 'WIRELINES'],
#        ['OHIO', 'CB-U-VERSE'],
#        ['OHIO', 'CB-WIRELINE'],
#        ['OHIO', 'U-VERSE'],
#        ['OHIO', 'U-VERSE'],
#        ['NEWYORK', 'WIRELINES'],
#        ['GEORGIA', 'U-VERSE'],
#        ['NEWYORK', 'WIRELINES'],
#        ['GEORGIA', 'U-VERSE'],
#        ['GEORGIA', 'U-VERSE'],
#        ['OHIO', 'CB-U-VERSE'],
#        ['GEORGIA', 'U-VERSE'],
#        ['TEXAS', 'WIRELESS'],
#        ['TEXAS', 'WIRELESS'],
#        ['TEXAS', 'WIRELESS'],
#        ['TEXAS', 'WIRELESS'],
#        ['TEXAS', 'WIRELESS'],
#        ['TEXAS', 'WIRELESS'],
#        ['TEXAS', 'WIRELESS'],
#        ['TEXAS', 'WIRELESS'],
#        ['TEXAS', 'WIRELESS'],
#        ['TEXAS', 'WIRELESS'],
#        ['TEXAS', 'WIRELESS'],
#        ['TEXAS', 'WIRELESS'],
#        ['TEXAS', 'WIRELESS'],
#        ['TEXAS', 'WIRELESS'],
#        ['TEXAS', 'WIRELESS'],
#        ['TEXAS', 'WIRELESS'],
#        ['TEXAS', 'WIRELESS'],
#        ['TEXAS', 'WIRELESS'],
#        ['TEXAS', 'WIRELESS'],
#        ['TEXAS', 'WIRELESS'],
#        ['TEXAS', 'WIRELESS'],
#        ['TEXAS', 'WIRELESS'],
#        ['TEXAS', 'WIRELESS'],
#        ['TEXAS', 'WIRELESS'],
#        ['TEXAS', 'WIRELESS'],
#        ['TEXAS', 'WIRELESS'],
#        ['TEXAS', 'WIRELESS'],
#        ['TEXAS', 'WIRELESS'],
#        ['TEXAS', 'WIRELESS'],
#        ['TEXAS', 'WIRELESS'],
#        ['TEXAS', 'WIRELESS'],
#        ['NEWYORK', 'WIRELESS'],
#        ['NEWYORK', 'WIRELESS'],
#        ['NEWYORK', 'WIRELESS'],
#        ['NEWYORK', 'WIRELESS'],
#        ['NEWYORK', 'WIRELESS'],
#        ['NEWYORK', 'WIRELESS'],
#        ['NEWYORK', 'WIRELESS'],
#        ['NEWYORK', 'WIRELESS'],
#        ['NEWYORK', 'WIRELESS'],
#        ['NEWYORK', 'WIRELESS'],
#        ['NEWYORK', 'WIRELESS'],
#        ['NEWYORK', 'WIRELESS'],
#        ['NEWYORK', 'WIRELESS'],
#        ['NEWYORK', 'WIRELESS'],
#        ['NEWYORK', 'WIRELESS'],
#        ['PENSELVANIYA', 'CB-U-VERSE'],
#        ['MISSOURI', 'Unified(Uverse+Wireless+DTV)'],
#        ['NEWYORK', 'WIRELESS'],
#        ['GEORGIA', 'U-VERSE'],
#        ['PENSELVANIYA', 'DirecTV'],
#        ['NEWYORK', 'WIRELINES'],
#        ['PENSELVANIYA', 'CB-U-VERSE'],
#        ['CALIFORNIA', 'WLL'],
#        ['TEXAS', 'Unified(Wireless+DTV)'],
#        ['GEORGIA', 'U-VERSE'],
#        ['MISSOURI', 'Unified(Uverse+Wireless+DTV)'],
#        ['NEWYORK', 'WIRELESS'],
#        ['NEWYORK', 'WIRELESS'],
#        ['MISSOURI', 'DirecTV'],
#        ['MISSOURI', 'DirecTV'],
#        ['NEWYORK', 'WIRELINES'],
#        ['NEWYORK', 'WIRELINES'],
#        ['NEWYORK', 'WIRELINES'],
#        ['NEWYORK', 'WIRELINES'],
#        ['MISSOURI', 'Unified(Uverse+Wireless+DTV)'],
#        ['GEORGIA', 'U-VERSE'],
#        ['GEORGIA', 'U-VERSE'],
#        ['GEORGIA', 'U-VERSE'],
#        ['GEORGIA', 'U-VERSE'],
#        ['CALIFORNIA', 'WLL'],
#        ['TEXAS', 'Unified(WLL+Wireless)'],
#        ['NEWYORK', 'WIRELESS'],
#        ['GEORGIA', 'U-VERSE'],
#        ['CALIFORNIA', 'WLL'],
#        ['MISSOURI', 'Unified(Uverse+Wireless+DTV)'],
#        ['NEWYORK', 'Unified(Wireless+DTV)'],
#        ['NEWYORK', 'Unified(Uverse+Wireless)'],
#        ['NEWYORK', 'WLL'],
#        ['NEWYORK', 'WLL'],
#        ['GEORGIA', 'U-VERSE'],
#        ['MISSOURI', 'Unified(Uverse+Wireless+DTV)'],
#        ['PENSELVANIYA', 'Unified(Uverse+Wireless+DTV)'],
#        ['NEWYORK', 'WIRELINES'],
#        ['NEWYORK', 'WIRELINES'],
#        ['GEORGIA', 'U-VERSE'],
#        ['GEORGIA', 'U-VERSE'],
#        ['NEWYORK', 'WIRELINES'],
#        ['NEWYORK', 'WLL'],
#        ['GEORGIA', 'U-VERSE'],
#        ['GEORGIA', 'U-VERSE'],
#        ['PENSELVANIYA', 'CB-U-VERSE'],
#        ['PENSELVANIYA', 'CB(Wireline+SynergyDTV)'],
#        ['NEWYORK', 'CB(SynergyDTV+3rdPartyWireline)'],
#        ['MISSOURI', 'CB(SynergyDTV+3rdPartyWireline)'],
#        ['OHIO', 'CB(Wireline+SynergyDTV)'],
#        ['NEWYORK', 'WIRELESS'],
#        ['NEWYORK', 'WIRELESS'],
#        ['NEWYORK', 'WIRELESS'],
#        ['NEWYORK', 'WIRELESS'],
#        ['NEWYORK', 'WIRELESS'],
#        ['NEWYORK', 'WIRELESS'],
#        ['NEWYORK', 'WIRELESS'],
#        ['NEWYORK', 'WIRELESS'],
#        ['NEWYORK', 'WIRELESS'],
#        ['NEWYORK', 'WIRELESS'],
#        ['NEWYORK', 'WIRELESS'],
#        ['NEWYORK', 'WIRELESS'],
#        ['NEWYORK', 'WIRELESS'],
#        ['NEWYORK', 'WIRELESS'],
#        ['NEWYORK', 'WIRELESS'],
#        ['NEWYORK', 'WIRELINES'],
#        ['NEWYORK', 'WIRELINES'],
#        ['NEWYORK', 'WIRELINES'],
#        ['NEWYORK', 'WIRELINES'],
#        ['NEWYORK', 'WIRELINES'],
#        ['GEORGIA', 'U-VERSE'],
#        ['GEORGIA', 'U-VERSE'],
#        ['NEWYORK', 'WIRELINES'],
#        ['ALABAMA', 'U-VERSE'],
#        ['ALABAMA', 'U-VERSE'],
#        ['NEWYORK', 'WIRELINES'],
#        ['ALABAMA', 'U-VERSE'],
#        ['ALABAMA', 'U-VERSE'],
#        ['ALABAMA', 'U-VERSE'],
#        ['ALABAMA', 'U-VERSE'],
#        ['ALABAMA', 'U-VERSE'],
#        ['NEWYORK', 'WIRELESS'],
#        ['NEWYORK', 'WIRELESS'],
#        ['NEWYORK', 'WIRELESS'],
#        ['ALABAMA', 'U-VERSE'],
#        ['NEWYORK', 'WIRELINES'],
#        ['NEWYORK', 'WIRELINES'],
#        ['MISSOURI', 'DirecTV'],
#        ['MISSOURI', 'DirecTV'],
#        ['MISSOURI', 'DirecTV'],
#        ['MISSOURI', 'Unified(Uverse+DTV)'],
#        ['PENSELVANIYA', 'Unified(Uverse+Wireless+DTV)'],
#        ['NEWYORK', 'WLL'],
#        ['ALABAMA', 'U-VERSE'],
#        ['PENSELVANIYA', 'WLL'],
#        ['ALABAMA', 'U-VERSE'],
#        ['PENSELVANIYA', 'CB-U-VERSE'],
#        ['OHIO', 'CB-WIRELINE'],
#        ['ALABAMA', 'U-VERSE'],
#        ['PENSELVANIYA', 'WLL'],
#        ['NEWYORK', 'WIRELINES'],
#        ['NEWYORK', 'WIRELINES'],
#        ['ALABAMA', 'U-VERSE'],
#        ['PENSELVANIYA', 'WLL'],
#        ['ALABAMA', 'U-VERSE'],
#        ['ALABAMA', 'U-VERSE'],
#        ['ALABAMA', 'U-VERSE'],
#        ['PENSELVANIYA', 'WLL'],
#        ['NEWYORK', 'WIRELINES'],
#        ['ALABAMA', 'U-VERSE'],
#        ['ALABAMA', 'U-VERSE'],
#        ['ALABAMA', 'U-VERSE'],
#        ['ALABAMA', 'U-VERSE'],
#        ['NEWYORK', 'WIRELESS'],
#        ['NEWYORK', 'WIRELESS'],
#        ['NEWYORK', 'WIRELESS'],
#        ['NEWYORK', 'WIRELESS'],
#        ['NEWYORK', 'WIRELESS'],
#        ['NEWYORK', 'WIRELESS'],
#        ['NEWYORK', 'WIRELESS'],
#        ['NEWYORK', 'WIRELESS'],
#        ['ALABAMA', 'U-VERSE'],
#        ['NEWYORK', 'WIRELESS'],
#        ['NEWYORK', 'WIRELESS'],
#        ['NEWYORK', 'WIRELESS'],
#        ['NEWYORK', 'WIRELINES'],
#        ['NEWYORK', 'WIRELINES'],
#        ['NEWYORK', 'WIRELESS'],
#        ['NEWYORK', 'WIRELESS'],
#        ['NEWYORK', 'WIRELESS'],
#        ['MISSOURI', 'DirecTV'],
#        ['MISSOURI', 'DirecTV'],
#        ['TEXAS', 'DirecTV'],
#        ['TEXAS', 'DirecTV'],
#        ['OHIO', 'Unified(Wireless+DTV)'],
#        ['PENSELVANIYA', 'Unified(Uverse+Wireless+DTV)'],
#        ['TEXAS', 'DirecTV'],
#        ['TEXAS', 'DirecTV'],
#        ['TEXAS', 'DirecTV'],
#        ['TEXAS', 'DirecTV'],
#        ['TEXAS', 'DirecTV'],
#        ['TEXAS', 'DirecTV'],
#        ['TEXAS', 'DirecTV'],
#        ['TEXAS', 'DirecTV'],
#        ['ALABAMA', 'DirecTV'],
#        ['ALABAMA', 'DirecTV'],
#        ['ALABAMA', 'DirecTV'],
#        ['ALABAMA', 'DirecTV'],
#        ['ALABAMA', 'DirecTV'],
#        ['ALABAMA', 'DirecTV'],
#        ['ALABAMA', 'DirecTV'],
#        ['ALABAMA', 'DirecTV'],
#        ['ALABAMA', 'DirecTV'],
#        ['NEWYORK', 'WIRELESS'],
#        ['ALABAMA', 'DirecTV'],
#        ['NEWYORK', 'WIRELESS'],
#        ['ALABAMA', 'DirecTV'],
#        ['NEWYORK', 'WIRELESS'],
#        ['ALABAMA', 'DirecTV'],
#        ['NEWYORK', 'WIRELESS'],
#        ['ALABAMA', 'DirecTV'],
#        ['NEWYORK', 'WIRELESS'],
#        ['ALABAMA', 'DirecTV'],
#        ['NEWYORK', 'DigitalLife'],
#        ['ALABAMA', 'DirecTV'],
#        ['MISSOURI', 'DigitalLife'],
#        ['ALABAMA', 'DirecTV'],
#        ['ALABAMA', 'DirecTV'],
#        ['ALABAMA', 'DirecTV'],
#        ['MISSOURI', 'DirecTV'],
#        ['MISSOURI', 'DirecTV'],
#        ['MISSOURI', 'DirecTV'],
#        ['MISSOURI', 'DirecTV'],
#        ['MISSOURI', 'DirecTV'],
#        ['MISSOURI', 'DirecTV'],
#        ['MISSOURI', 'DirecTV'],
#        ['MISSOURI', 'DirecTV'],
#        ['MISSOURI', 'DirecTV'],
#        ['MISSOURI', 'DirecTV'],
#        ['MISSOURI', 'DirecTV'],
#        ['MISSOURI', 'DirecTV'],
#        ['MISSOURI', 'DirecTV'],
#        ['MISSOURI', 'DirecTV'],
#        ['MISSOURI', 'DirecTV'],
#        ['MISSOURI', 'DirecTV'],
#        ['MISSOURI', 'DirecTV'],
#        ['MISSOURI', 'DirecTV'],
#        ['MISSOURI', 'DirecTV'],
#        ['MISSOURI', 'DirecTV'],
#        ['NEWYORK', 'DirecTV'],
#        ['NEWYORK', 'DirecTV'],
#        ['NEWYORK', 'DirecTV'],
#        ['NEWYORK', 'DirecTV'],
#        ['NEWYORK', 'DirecTV'],
#        ['NEWYORK', 'DirecTV'],
#        ['NEWYORK', 'DirecTV'],
#        ['NEWYORK', 'DirecTV'],
#        ['NEWYORK', 'DirecTV'],
#        ['NEWYORK', 'DirecTV']],
#       dtype='|S31')

# %%
from numpy import *

# %% [markdown]
# # Analyzing ATT data sets with Apriori algorithm

# %% [raw]
# I have taken everything form only one article[1] and I have mentioned it below.

# %% [raw]
# Apriori uses a breadth-first search strategy to count the support of itemsets and uses a candidate generation function which exploits the downward closure property of support.

# %% [raw]
# The Apriori algorithm principle says that if an itemset is frequent, then all of its subsets are frequent.this means that if {0,1} is frequent, then {0} and {1} have to be frequent.
#
# The rule turned around says that if an itemset is infrequent, then its supersets are also infrequent.
#
# We first need to find the frequent itemsets, and then we can find association rules.

# %% [raw]
# Interesting relationships can take two forms: frequent item sets or association rules.
# Frequent item sets are a collection of items that frequently occur together. The second way to view interesting relationships is association rules. Association rules suggest that a strong relationship exists between two items.
#
# With the frequent item sets and association rules, retailers have a much better understanding of their customers. Another example is search terms from a search engine.

# %% [raw]
# General approach to the Apriori algorithm
#
# Collect: Any method.
# Prepare: Any data type will work as we’re storing sets.
# Analyze: Any method.
# Train: Use the Apriori algorithm to find frequent itemsets.
# Test: Doesn’t apply.
# Use: This will be used to find frequent itemsets and association rules between items.

# %% [raw]
# The way to find frequent itemsets is the Apriori algorithm. The Apriori algorithm needs a minimum support level as an input and a data set. The algorithm will generate a list of all candidate itemsets with one item. The transaction data set will then be scanned to see which sets meet the minimum support level. Sets that don’t meet the minimum support level will get tossed out. The remaining sets will then be combined to make itemsets with two elements. Again, the transaction dataset will be scanned and itemsets not meeting the minimum support level will get tossed. This procedure will be repeated until all sets are tossed out.

# %% [raw]
# It creates C1 .C1 is a candidate itemset of size one. In the Apriori algorithm, we create C1, and then we’ll scan the dataset to see if these one itemsets meet our minimum support requirements. The itemsets that do meet our minimum requirements become L1. L1 then gets combined to become C2 and C2 will get filtered to become L2.
#
# Frozensets are sets that are frozen, which means they’re immutable; you can’t change them. You need to use the type frozenset instead of set because you’ll later use these sets as the key in a dictionary.
#
# You can’t create a set of just one integer in Python. It needs to be a list (try it out). That’s why you create a list of single-item lists. Finally, you sort the list and then map every item in the list to frozenset() and return this list of frozensets

# %%
def createC1(dataSet):
    C1 = []
    for transaction in dataSet:
        for item in transaction:
            if not [item] in C1:
                C1.append([item])
                
    C1.sort()
    return list(map(frozenset, C1))#use frozen set so we
                            #can use it as a key in a dict

# %%
C1 = createC1(a)
C1
# Out:
# [frozenset({'ALABAMA'}),
#  frozenset({'CALIFORNIA'}),
#  frozenset({'CB(SynergyDTV+3rdPartyWireline)'}),
#  frozenset({'CB(Wireline+SynergyDTV)'}),
#  frozenset({'CB-U-VERSE'}),
#  frozenset({'CB-WIRELINE'}),
#  frozenset({'DigitalLife'}),
#  frozenset({'DirecTV'}),
#  frozenset({'GEORGIA'}),
#  frozenset({'INDIANA'}),
#  frozenset({'MISSOURI'}),
#  frozenset({'NEWYORK'}),
#  frozenset({'OHIO'}),
#  frozenset({'OPENPORTAL'}),
#  frozenset({'PENSELVANIYA'}),
#  frozenset({'TEXAS'}),
#  frozenset({'U-VERSE'}),
#  frozenset({'Unified(Uverse+DTV)'}),
#  frozenset({'Unified(Uverse+Wireless)'}),
#  frozenset({'Unified(Uverse+Wireless+DTV)'}),
#  frozenset({'Unified(WLL+DTV)'}),
#  frozenset({'Unified(WLL+Wireless)'}),
#  frozenset({'Unified(WLL+Wireless+DTV)'}),
#  frozenset({'Unified(Wireless+DTV)'}),
#  frozenset({'WIRELESS'}),
#  frozenset({'WIRELINES'}),
#  frozenset({'WLL'})]

# %% [raw]
# This function takes three arguments: a dataset, Ck, a list of candidate sets, and minSupport, which is the minimum support you’re interested in. This is the function you’ll use to generate L1 from C1. Additionally, this function returns a dictionary with support values.

# %%
def scanD(D, Ck, minSupport):
    ssCnt = {}
    for tid in D:
        for can in Ck:
            if can.issubset(tid):
                if not can in ssCnt: ssCnt[can]=1
                else: ssCnt[can] += 1
    numItems = float(len(D))
    retList = []
    supportData = {}
    for key in ssCnt:
        support = ssCnt[key]/numItems
        if support >= minSupport:
            retList.insert(0,key)
        supportData[key] = support
    return retList, supportData

# %%
D = list(map(set,a))
D
# Out:
# [{'OHIO', 'WIRELESS'},
#  {'OHIO', 'WIRELESS'},
#  {'OHIO', 'WIRELESS'},
#  {'OHIO', 'WIRELESS'},
#  {'OHIO', 'WIRELESS'},
#  {'OHIO', 'WIRELESS'},
#  {'OHIO', 'WIRELESS'},
#  {'OHIO', 'WIRELESS'},
#  {'OHIO', 'WIRELESS'},
#  {'OHIO', 'WIRELESS'},
#  {'OHIO', 'WIRELESS'},
#  {'OHIO', 'WIRELESS'},
#  {'OHIO', 'WIRELESS'},
#  {'OHIO', 'WIRELESS'},
#  {'OHIO', 'WIRELESS'},
#  {'OHIO', 'WIRELESS'},
#  {'OHIO', 'WIRELESS'},
#  {'OHIO', 'WIRELESS'},
#  {'INDIANA', 'WIRELESS'},
#  {'INDIANA', 'WIRELESS'},
#  {'INDIANA', 'WIRELESS'},
#  {'INDIANA', 'WIRELESS'},
#  {'INDIANA', 'WIRELESS'},
#  {'INDIANA', 'WIRELESS'},
#  {'INDIANA', 'WIRELESS'},
#  {'INDIANA', 'WIRELESS'},
#  {'INDIANA', 'WIRELESS'},
#  {'INDIANA', 'WIRELESS'},
#  {'INDIANA', 'WIRELESS'},
#  {'INDIANA', 'WIRELESS'},
#  {'INDIANA', 'WIRELESS'},
#  {'INDIANA', 'WIRELESS'},
#  {'DirecTV', 'TEXAS'},
#  {'DirecTV', 'NEWYORK'},
#  {'NEWYORK', 'WIRELINES'},
#  {'DirecTV', 'NEWYORK'},
#  {'ALABAMA', 'WIRELESS'},
#  {'ALABAMA', 'WIRELESS'},
#  {'NEWYORK', 'U-VERSE'},
#  {'NEWYORK', 'Unified(WLL+Wireless+DTV)'},
#  {'PENSELVANIYA', 'U-VERSE'},
#  {'TEXAS', 'WIRELINES'},
#  {'TEXAS', 'WIRELINES'},
#  {'TEXAS', 'WIRELINES'},
#  {'NEWYORK', 'U-VERSE'},
#  {'CALIFORNIA', 'WLL'},
#  {'CALIFORNIA', 'WLL'},
#  {'CALIFORNIA', 'WLL'},
#  {'ALABAMA', 'WIRELESS'},
#  {'ALABAMA', 'WIRELESS'},
#  {'ALABAMA', 'WIRELESS'},
#  {'CB(SynergyDTV+3rdPartyWireline)', 'NEWYORK'},
#  {'CB(SynergyDTV+3rdPartyWireline)', 'NEWYORK'},
#  {'CB(SynergyDTV+3rdPartyWireline)', 'NEWYORK'},
#  {'NEWYORK', 'Unified(Uverse+Wireless+DTV)'},
#  {'TEXAS', 'WIRELINES'},
#  {'TEXAS', 'WIRELINES'},
#  {'TEXAS', 'WIRELINES'},
#  {'TEXAS', 'WIRELINES'},
#  {'ALABAMA', 'WIRELESS'},
#  {'ALABAMA', 'WIRELESS'},
#  {'ALABAMA', 'WIRELESS'},
#  {'TEXAS', 'WIRELINES'},
#  {'NEWYORK', 'WIRELESS'},
#  {'TEXAS', 'WIRELESS'},
#  {'NEWYORK', 'Unified(Uverse+Wireless+DTV)'},
#  {'CB-WIRELINE', 'PENSELVANIYA'},
#  {'TEXAS', 'WIRELINES'},
#  {'MISSOURI', 'WIRELESS'},
#  {'ALABAMA', 'WIRELESS'},
#  {'ALABAMA', 'WIRELESS'},
#  {'ALABAMA', 'WIRELESS'},
#  {'ALABAMA', 'WIRELESS'},
#  {'NEWYORK', 'U-VERSE'},
#  {'TEXAS', 'WIRELINES'},
#  {'NEWYORK', 'U-VERSE'},
#  {'PENSELVANIYA', 'WIRELINES'},
#  {'PENSELVANIYA', 'WIRELINES'},
#  {'ALABAMA', 'WIRELESS'},
#  {'NEWYORK', 'U-VERSE'},
#  {'DirecTV', 'NEWYORK'},
#  {'PENSELVANIYA', 'WIRELINES'},
#  {'NEWYORK', 'OPENPORTAL'},
#  {'OPENPORTAL', 'PENSELVANIYA'},
#  {'MISSOURI', 'OPENPORTAL'},
#  {'NEWYORK', 'Unified(Uverse+DTV)'},
#  {'PENSELVANIYA', 'Unified(Uverse+DTV)'},
#  {'DirecTV', 'NEWYORK'},
#  {'DirecTV', 'NEWYORK'},
#  {'NEWYORK', 'U-VERSE'},
#  {'NEWYORK', 'U-VERSE'},
#  {'PENSELVANIYA', 'WIRELINES'},
#  {'PENSELVANIYA', 'WIRELINES'},
#  {'PENSELVANIYA', 'WIRELINES'},
#  {'PENSELVANIYA', 'WIRELINES'},
#  {'PENSELVANIYA', 'WIRELINES'},
#  {'PENSELVANIYA', 'WIRELINES'},
#  {'PENSELVANIYA', 'WIRELINES'},
#  {'PENSELVANIYA', 'WIRELINES'},
#  {'PENSELVANIYA', 'WIRELINES'},
#  {'PENSELVANIYA', 'WIRELINES'},
#  {'PENSELVANIYA', 'WIRELINES'},
#  {'PENSELVANIYA', 'WIRELINES'},
#  {'DirecTV', 'NEWYORK'},
#  {'DirecTV', 'NEWYORK'},
#  {'DirecTV', 'NEWYORK'},
#  {'DirecTV', 'NEWYORK'},
#  {'DirecTV', 'NEWYORK'},
#  {'DirecTV', 'NEWYORK'},
#  {'DirecTV', 'NEWYORK'},
#  {'DirecTV', 'NEWYORK'},
#  {'DirecTV', 'NEWYORK'},
#  {'ALABAMA', 'WIRELESS'},
#  {'ALABAMA', 'WIRELESS'},
#  {'ALABAMA', 'WIRELESS'},
#  {'ALABAMA', 'WIRELESS'},
#  {'ALABAMA', 'WIRELESS'},
#  {'ALABAMA', 'WIRELESS'},
#  {'ALABAMA', 'WIRELESS'},
#  {'NEWYORK', 'U-VERSE'},
#  {'NEWYORK', 'U-VERSE'},
#  {'OHIO', 'Unified(Uverse+DTV)'},
#  {'NEWYORK', 'U-VERSE'},
#  {'DirecTV', 'NEWYORK'},
#  {'TEXAS', 'Unified(Uverse+DTV)'},
#  {'TEXAS', 'Unified(Wireless+DTV)'},
#  {'NEWYORK', 'Unified(Uverse+Wireless+DTV)'},
#  {'NEWYORK', 'Unified(Uverse+Wireless+DTV)'},
#  {'ALABAMA', 'WIRELESS'},
#  {'ALABAMA', 'WIRELESS'},
#  {'MISSOURI', 'WIRELESS'},
#  {'MISSOURI', 'WIRELESS'},
#  {'MISSOURI', 'WIRELESS'},
#  {'MISSOURI', 'WIRELESS'},
#  {'MISSOURI', 'WIRELESS'},
#  {'MISSOURI', 'WIRELESS'},
#  {'MISSOURI', 'WIRELESS'},
#  {'MISSOURI', 'WIRELESS'},
#  {'MISSOURI', 'WIRELESS'},
#  {'MISSOURI', 'WIRELESS'},
#  {'MISSOURI', 'WIRELESS'},
#  {'MISSOURI', 'WIRELESS'},
#  {'MISSOURI', 'WIRELESS'},
#  {'MISSOURI', 'WIRELESS'},
#  {'MISSOURI', 'WIRELESS'},
#  {'NEWYORK', 'Unified(Uverse+DTV)'},
#  {'DirecTV', 'NEWYORK'},
#  {'PENSELVANIYA', 'WIRELINES'},
#  {'DirecTV', 'PENSELVANIYA'},
#  {'DirecTV', 'PENSELVANIYA'},
#  {'PENSELVANIYA', 'WIRELINES'},
#  {'PENSELVANIYA', 'WIRELINES'},
#  {'PENSELVANIYA', 'WIRELINES'},
#  {'PENSELVANIYA', 'WIRELINES'},
#  {'CB-WIRELINE', 'MISSOURI'},
#  {'CB-WIRELINE', 'OHIO'},
#  {'NEWYORK', 'U-VERSE'},
#  {'NEWYORK', 'U-VERSE'},
#  {'NEWYORK', 'U-VERSE'},
#  {'NEWYORK', 'U-VERSE'},
#  {'OHIO', 'U-VERSE'},
#  {'OHIO', 'U-VERSE'},
#  {'OHIO', 'U-VERSE'},
#  {'OHIO', 'U-VERSE'},
#  {'DirecTV', 'PENSELVANIYA'},
#  {'DirecTV', 'PENSELVANIYA'},
#  {'DirecTV', 'PENSELVANIYA'},
#  {'MISSOURI', 'WIRELESS'},
#  {'MISSOURI', 'WIRELESS'},
#  {'MISSOURI', 'WIRELESS'},
#  {'MISSOURI', 'WIRELESS'},
#  {'MISSOURI', 'WIRELESS'},
#  {'MISSOURI', 'WIRELESS'},
#  {'OHIO', 'U-VERSE'},
#  {'PENSELVANIYA', 'WIRELINES'},
#  {'MISSOURI', 'WIRELESS'},
#  {'OHIO', 'U-VERSE'},
#  {'PENSELVANIYA', 'WIRELINES'},
#  {'CB-U-VERSE', 'OHIO'},
#  {'CB-WIRELINE', 'OHIO'},
#  {'OHIO', 'U-VERSE'},
#  {'OHIO', 'U-VERSE'},
#  {'MISSOURI', 'WIRELESS'},
#  {'OHIO', 'U-VERSE'},
#  {'TEXAS', 'WIRELESS'},
#  {'OHIO', 'U-VERSE'},
#  {'NEWYORK', 'WIRELINES'},
#  {'TEXAS', 'WIRELESS'},
#  {'TEXAS', 'WIRELESS'},
#  {'TEXAS', 'WIRELESS'},
#  {'TEXAS', 'WIRELESS'},
#  {'TEXAS', 'WIRELESS'},
#  {'DirecTV', 'PENSELVANIYA'},
#  {'NEWYORK', 'Unified(WLL+Wireless)'},
#  {'TEXAS', 'Unified(Wireless+DTV)'},
#  {'DirecTV', 'PENSELVANIYA'},
#  {'DirecTV', 'PENSELVANIYA'},
#  {'PENSELVANIYA', 'Unified(WLL+DTV)'},
#  {'NEWYORK', 'Unified(WLL+Wireless+DTV)'},
#  {'CALIFORNIA', 'WLL'},
#  {'CALIFORNIA', 'WLL'},
#  {'OHIO', 'U-VERSE'},
#  {'OHIO', 'U-VERSE'},
#  {'OHIO', 'U-VERSE'},
#  {'NEWYORK', 'WIRELINES'},
#  {'CB-U-VERSE', 'OHIO'},
#  {'CB-WIRELINE', 'OHIO'},
#  {'OHIO', 'U-VERSE'},
#  {'OHIO', 'U-VERSE'},
#  {'NEWYORK', 'WIRELINES'},
#  {'GEORGIA', 'U-VERSE'},
#  {'NEWYORK', 'WIRELINES'},
#  {'GEORGIA', 'U-VERSE'},
#  {'GEORGIA', 'U-VERSE'},
#  {'CB-U-VERSE', 'OHIO'},
#  {'GEORGIA', 'U-VERSE'},
#  {'TEXAS', 'WIRELESS'},
#  {'TEXAS', 'WIRELESS'},
#  {'TEXAS', 'WIRELESS'},
#  {'TEXAS', 'WIRELESS'},
#  {'TEXAS', 'WIRELESS'},
#  {'TEXAS', 'WIRELESS'},
#  {'TEXAS', 'WIRELESS'},
#  {'TEXAS', 'WIRELESS'},
#  {'TEXAS', 'WIRELESS'},
#  {'TEXAS', 'WIRELESS'},
#  {'TEXAS', 'WIRELESS'},
#  {'TEXAS', 'WIRELESS'},
#  {'TEXAS', 'WIRELESS'},
#  {'TEXAS', 'WIRELESS'},
#  {'TEXAS', 'WIRELESS'},
#  {'TEXAS', 'WIRELESS'},
#  {'TEXAS', 'WIRELESS'},
#  {'TEXAS', 'WIRELESS'},
#  {'TEXAS', 'WIRELESS'},
#  {'TEXAS', 'WIRELESS'},
#  {'TEXAS', 'WIRELESS'},
#  {'TEXAS', 'WIRELESS'},
#  {'TEXAS', 'WIRELESS'},
#  {'TEXAS', 'WIRELESS'},
#  {'TEXAS', 'WIRELESS'},
#  {'TEXAS', 'WIRELESS'},
#  {'TEXAS', 'WIRELESS'},
#  {'TEXAS', 'WIRELESS'},
#  {'TEXAS', 'WIRELESS'},
#  {'TEXAS', 'WIRELESS'},
#  {'TEXAS', 'WIRELESS'},
#  {'NEWYORK', 'WIRELESS'},
#  {'NEWYORK', 'WIRELESS'},
#  {'NEWYORK', 'WIRELESS'},
#  {'NEWYORK', 'WIRELESS'},
#  {'NEWYORK', 'WIRELESS'},
#  {'NEWYORK', 'WIRELESS'},
#  {'NEWYORK', 'WIRELESS'},
#  {'NEWYORK', 'WIRELESS'},
#  {'NEWYORK', 'WIRELESS'},
#  {'NEWYORK', 'WIRELESS'},
#  {'NEWYORK', 'WIRELESS'},
#  {'NEWYORK', 'WIRELESS'},
#  {'NEWYORK', 'WIRELESS'},
#  {'NEWYORK', 'WIRELESS'},
#  {'NEWYORK', 'WIRELESS'},
#  {'CB-U-VERSE', 'PENSELVANIYA'},
#  {'MISSOURI', 'Unified(Uverse+Wireless+DTV)'},
#  {'NEWYORK', 'WIRELESS'},
#  {'GEORGIA', 'U-VERSE'},
#  {'DirecTV', 'PENSELVANIYA'},
#  {'NEWYORK', 'WIRELINES'},
#  {'CB-U-VERSE', 'PENSELVANIYA'},
#  {'CALIFORNIA', 'WLL'},
#  {'TEXAS', 'Unified(Wireless+DTV)'},
#  {'GEORGIA', 'U-VERSE'},
#  {'MISSOURI', 'Unified(Uverse+Wireless+DTV)'},
#  {'NEWYORK', 'WIRELESS'},
#  {'NEWYORK', 'WIRELESS'},
#  {'DirecTV', 'MISSOURI'},
#  {'DirecTV', 'MISSOURI'},
#  {'NEWYORK', 'WIRELINES'},
#  {'NEWYORK', 'WIRELINES'},
#  {'NEWYORK', 'WIRELINES'},
#  {'NEWYORK', 'WIRELINES'},
#  {'MISSOURI', 'Unified(Uverse+Wireless+DTV)'},
#  {'GEORGIA', 'U-VERSE'},
#  {'GEORGIA', 'U-VERSE'},
#  {'GEORGIA', 'U-VERSE'},
#  {'GEORGIA', 'U-VERSE'},
#  {'CALIFORNIA', 'WLL'},
#  {'TEXAS', 'Unified(WLL+Wireless)'},
#  {'NEWYORK', 'WIRELESS'},
#  {'GEORGIA', 'U-VERSE'},
#  {'CALIFORNIA', 'WLL'},
#  {'MISSOURI', 'Unified(Uverse+Wireless+DTV)'},
#  {'NEWYORK', 'Unified(Wireless+DTV)'},
#  {'NEWYORK', 'Unified(Uverse+Wireless)'},
#  {'NEWYORK', 'WLL'},
#  {'NEWYORK', 'WLL'},
#  {'GEORGIA', 'U-VERSE'},
#  {'MISSOURI', 'Unified(Uverse+Wireless+DTV)'},
#  {'PENSELVANIYA', 'Unified(Uverse+Wireless+DTV)'},
#  {'NEWYORK', 'WIRELINES'},
#  {'NEWYORK', 'WIRELINES'},
#  {'GEORGIA', 'U-VERSE'},
#  {'GEORGIA', 'U-VERSE'},
#  {'NEWYORK', 'WIRELINES'},
#  {'NEWYORK', 'WLL'},
#  {'GEORGIA', 'U-VERSE'},
#  {'GEORGIA', 'U-VERSE'},
#  {'CB-U-VERSE', 'PENSELVANIYA'},
#  {'CB(Wireline+SynergyDTV)', 'PENSELVANIYA'},
#  {'CB(SynergyDTV+3rdPartyWireline)', 'NEWYORK'},
#  {'CB(SynergyDTV+3rdPartyWireline)', 'MISSOURI'},
#  {'CB(Wireline+SynergyDTV)', 'OHIO'},
#  {'NEWYORK', 'WIRELESS'},
#  {'NEWYORK', 'WIRELESS'},
#  {'NEWYORK', 'WIRELESS'},
#  {'NEWYORK', 'WIRELESS'},
#  {'NEWYORK', 'WIRELESS'},
#  {'NEWYORK', 'WIRELESS'},
#  {'NEWYORK', 'WIRELESS'},
#  {'NEWYORK', 'WIRELESS'},
#  {'NEWYORK', 'WIRELESS'},
#  {'NEWYORK', 'WIRELESS'},
#  {'NEWYORK', 'WIRELESS'},
#  {'NEWYORK', 'WIRELESS'},
#  {'NEWYORK', 'WIRELESS'},
#  {'NEWYORK', 'WIRELESS'},
#  {'NEWYORK', 'WIRELESS'},
#  {'NEWYORK', 'WIRELINES'},
#  {'NEWYORK', 'WIRELINES'},
#  {'NEWYORK', 'WIRELINES'},
#  {'NEWYORK', 'WIRELINES'},
#  {'NEWYORK', 'WIRELINES'},
#  {'GEORGIA', 'U-VERSE'},
#  {'GEORGIA', 'U-VERSE'},
#  {'NEWYORK', 'WIRELINES'},
#  {'ALABAMA', 'U-VERSE'},
#  {'ALABAMA', 'U-VERSE'},
#  {'NEWYORK', 'WIRELINES'},
#  {'ALABAMA', 'U-VERSE'},
#  {'ALABAMA', 'U-VERSE'},
#  {'ALABAMA', 'U-VERSE'},
#  {'ALABAMA', 'U-VERSE'},
#  {'ALABAMA', 'U-VERSE'},
#  {'NEWYORK', 'WIRELESS'},
#  {'NEWYORK', 'WIRELESS'},
#  {'NEWYORK', 'WIRELESS'},
#  {'ALABAMA', 'U-VERSE'},
#  {'NEWYORK', 'WIRELINES'},
#  {'NEWYORK', 'WIRELINES'},
#  {'DirecTV', 'MISSOURI'},
#  {'DirecTV', 'MISSOURI'},
#  {'DirecTV', 'MISSOURI'},
#  {'MISSOURI', 'Unified(Uverse+DTV)'},
#  {'PENSELVANIYA', 'Unified(Uverse+Wireless+DTV)'},
#  {'NEWYORK', 'WLL'},
#  {'ALABAMA', 'U-VERSE'},
#  {'PENSELVANIYA', 'WLL'},
#  {'ALABAMA', 'U-VERSE'},
#  {'CB-U-VERSE', 'PENSELVANIYA'},
#  {'CB-WIRELINE', 'OHIO'},
#  {'ALABAMA', 'U-VERSE'},
#  {'PENSELVANIYA', 'WLL'},
#  {'NEWYORK', 'WIRELINES'},
#  {'NEWYORK', 'WIRELINES'},
#  {'ALABAMA', 'U-VERSE'},
#  {'PENSELVANIYA', 'WLL'},
#  {'ALABAMA', 'U-VERSE'},
#  {'ALABAMA', 'U-VERSE'},
#  {'ALABAMA', 'U-VERSE'},
#  {'PENSELVANIYA', 'WLL'},
#  {'NEWYORK', 'WIRELINES'},
#  {'ALABAMA', 'U-VERSE'},
#  {'ALABAMA', 'U-VERSE'},
#  {'ALABAMA', 'U-VERSE'},
#  {'ALABAMA', 'U-VERSE'},
#  {'NEWYORK', 'WIRELESS'},
#  {'NEWYORK', 'WIRELESS'},
#  {'NEWYORK', 'WIRELESS'},
#  {'NEWYORK', 'WIRELESS'},
#  {'NEWYORK', 'WIRELESS'},
#  {'NEWYORK', 'WIRELESS'},
#  {'NEWYORK', 'WIRELESS'},
#  {'NEWYORK', 'WIRELESS'},
#  {'ALABAMA', 'U-VERSE'},
#  {'NEWYORK', 'WIRELESS'},
#  {'NEWYORK', 'WIRELESS'},
#  {'NEWYORK', 'WIRELESS'},
#  {'NEWYORK', 'WIRELINES'},
#  {'NEWYORK', 'WIRELINES'},
#  {'NEWYORK', 'WIRELESS'},
#  {'NEWYORK', 'WIRELESS'},
#  {'NEWYORK', 'WIRELESS'},
#  {'DirecTV', 'MISSOURI'},
#  {'DirecTV', 'MISSOURI'},
#  {'DirecTV', 'TEXAS'},
#  {'DirecTV', 'TEXAS'},
#  {'OHIO', 'Unified(Wireless+DTV)'},
#  {'PENSELVANIYA', 'Unified(Uverse+Wireless+DTV)'},
#  {'DirecTV', 'TEXAS'},
#  {'DirecTV', 'TEXAS'},
#  {'DirecTV', 'TEXAS'},
#  {'DirecTV', 'TEXAS'},
#  {'DirecTV', 'TEXAS'},
#  {'DirecTV', 'TEXAS'},
#  {'DirecTV', 'TEXAS'},
#  {'DirecTV', 'TEXAS'},
#  {'ALABAMA', 'DirecTV'},
#  {'ALABAMA', 'DirecTV'},
#  {'ALABAMA', 'DirecTV'},
#  {'ALABAMA', 'DirecTV'},
#  {'ALABAMA', 'DirecTV'},
#  {'ALABAMA', 'DirecTV'},
#  {'ALABAMA', 'DirecTV'},
#  {'ALABAMA', 'DirecTV'},
#  {'ALABAMA', 'DirecTV'},
#  {'NEWYORK', 'WIRELESS'},
#  {'ALABAMA', 'DirecTV'},
#  {'NEWYORK', 'WIRELESS'},
#  {'ALABAMA', 'DirecTV'},
#  {'NEWYORK', 'WIRELESS'},
#  {'ALABAMA', 'DirecTV'},
#  {'NEWYORK', 'WIRELESS'},
#  {'ALABAMA', 'DirecTV'},
#  {'NEWYORK', 'WIRELESS'},
#  {'ALABAMA', 'DirecTV'},
#  {'DigitalLife', 'NEWYORK'},
#  {'ALABAMA', 'DirecTV'},
#  {'DigitalLife', 'MISSOURI'},
#  {'ALABAMA', 'DirecTV'},
#  {'ALABAMA', 'DirecTV'},
#  {'ALABAMA', 'DirecTV'},
#  {'DirecTV', 'MISSOURI'},
#  {'DirecTV', 'MISSOURI'},
#  {'DirecTV', 'MISSOURI'},
#  {'DirecTV', 'MISSOURI'},
#  {'DirecTV', 'MISSOURI'},
#  {'DirecTV', 'MISSOURI'},
#  {'DirecTV', 'MISSOURI'},
#  {'DirecTV', 'MISSOURI'},
#  {'DirecTV', 'MISSOURI'},
#  {'DirecTV', 'MISSOURI'},
#  {'DirecTV', 'MISSOURI'},
#  {'DirecTV', 'MISSOURI'},
#  {'DirecTV', 'MISSOURI'},
#  {'DirecTV', 'MISSOURI'},
#  {'DirecTV', 'MISSOURI'},
#  {'DirecTV', 'MISSOURI'},
#  {'DirecTV', 'MISSOURI'},
#  {'DirecTV', 'MISSOURI'},
#  {'DirecTV', 'MISSOURI'},
#  {'DirecTV', 'MISSOURI'},
#  {'DirecTV', 'NEWYORK'},
#  {'DirecTV', 'NEWYORK'},
#  {'DirecTV', 'NEWYORK'},
#  {'DirecTV', 'NEWYORK'},
#  {'DirecTV', 'NEWYORK'},
#  {'DirecTV', 'NEWYORK'},
#  {'DirecTV', 'NEWYORK'},
#  {'DirecTV', 'NEWYORK'},
#  {'DirecTV', 'NEWYORK'},
#  {'DirecTV', 'NEWYORK'}]

# %%
L1,suppDat0 = scanD(D,C1,0.01)
L1
# Out:
# [frozenset({'DirecTV'}),
#  frozenset({'CB-WIRELINE'}),
#  frozenset({'U-VERSE'}),
#  frozenset({'CB-U-VERSE'}),
#  frozenset({'GEORGIA'}),
#  frozenset({'Unified(Uverse+DTV)'}),
#  frozenset({'WIRELESS'}),
#  frozenset({'INDIANA'}),
#  frozenset({'CALIFORNIA'}),
#  frozenset({'Unified(Wireless+DTV)'}),
#  frozenset({'TEXAS'}),
#  frozenset({'CB(SynergyDTV+3rdPartyWireline)'}),
#  frozenset({'MISSOURI'}),
#  frozenset({'OHIO'}),
#  frozenset({'NEWYORK'}),
#  frozenset({'WIRELINES'}),
#  frozenset({'PENSELVANIYA'}),
#  frozenset({'Unified(Uverse+Wireless+DTV)'}),
#  frozenset({'ALABAMA'}),
#  frozenset({'WLL'})]

# %% [raw]
# The main function is apriori(); it calls aprioriGen() to create candidate itemsets: Ck.
#
# The function aprioriGen() will take a list of frequent itemsets, Lk, and the size of the itemsets, k, to produce Ck. For example, it will take the itemsets {0}, {1}, {2} and so on and produce {0,1} {0,2}, and {1,2}.
#
# The sets are combined using the set union, which is the | symbol in Python.

# %%
def aprioriGen(Lk, k): #creates Ck
    retList = []
    lenLk = len(Lk)
    for i in range(lenLk):
        for j in range(i+1, lenLk): 
            L1 = list(Lk[i])[:k-2]; L2 = list(Lk[j])[:k-2]
            L1.sort(); L2.sort()
            if L1==L2: #if first k-2 elements are equal
                retList.append(Lk[i] | Lk[j]) #set union
    return retList

# %%
def apriori(dataSet, minSupport = 0.1):
    C1 = createC1(dataSet)
    D = list(map(set, dataSet))
    L1, supportData = scanD(D, C1, minSupport)
    L = [L1]
    k = 2
    while (len(L[k-2]) > 0):
        Ck = aprioriGen(L[k-2], k)
        Lk, supK = scanD(D, Ck, minSupport)#scan DB to get Lk
        supportData.update(supK)
        L.append(Lk)
        k += 1
    return L, supportData

# %%
L,suppData = apriori(a)
L
# Out:
# [[frozenset({'DirecTV'}),
#   frozenset({'U-VERSE'}),
#   frozenset({'WIRELESS'}),
#   frozenset({'TEXAS'}),
#   frozenset({'MISSOURI'}),
#   frozenset({'NEWYORK'}),
#   frozenset({'WIRELINES'}),
#   frozenset({'PENSELVANIYA'}),
#   frozenset({'ALABAMA'})],
#  [frozenset({'NEWYORK', 'WIRELESS'})],
#  []]

# %%
L[0]
# Out:
# [frozenset({'DirecTV'}),
#  frozenset({'U-VERSE'}),
#  frozenset({'WIRELESS'}),
#  frozenset({'TEXAS'}),
#  frozenset({'MISSOURI'}),
#  frozenset({'NEWYORK'}),
#  frozenset({'WIRELINES'}),
#  frozenset({'PENSELVANIYA'}),
#  frozenset({'ALABAMA'})]

# %%
L[1]
# Out:
# [frozenset({'NEWYORK', 'WIRELESS'})]

# %%
aprioriGen(L[0],2)
# Out:
# [frozenset({'DirecTV', 'U-VERSE'}),
#  frozenset({'DirecTV', 'WIRELESS'}),
#  frozenset({'DirecTV', 'TEXAS'}),
#  frozenset({'DirecTV', 'MISSOURI'}),
#  frozenset({'DirecTV', 'NEWYORK'}),
#  frozenset({'DirecTV', 'WIRELINES'}),
#  frozenset({'DirecTV', 'PENSELVANIYA'}),
#  frozenset({'ALABAMA', 'DirecTV'}),
#  frozenset({'U-VERSE', 'WIRELESS'}),
#  frozenset({'TEXAS', 'U-VERSE'}),
#  frozenset({'MISSOURI', 'U-VERSE'}),
#  frozenset({'NEWYORK', 'U-VERSE'}),
#  frozenset({'U-VERSE', 'WIRELINES'}),
#  frozenset({'PENSELVANIYA', 'U-VERSE'}),
#  frozenset({'ALABAMA', 'U-VERSE'}),
#  frozenset({'TEXAS', 'WIRELESS'}),
#  frozenset({'MISSOURI', 'WIRELESS'}),
#  frozenset({'NEWYORK', 'WIRELESS'}),
#  frozenset({'WIRELESS', 'WIRELINES'}),
#  frozenset({'PENSELVANIYA', 'WIRELESS'}),
#  frozenset({'ALABAMA', 'WIRELESS'}),
#  frozenset({'MISSOURI', 'TEXAS'}),
#  frozenset({'NEWYORK', 'TEXAS'}),
#  frozenset({'TEXAS', 'WIRELINES'}),
#  frozenset({'PENSELVANIYA', 'TEXAS'}),
#  frozenset({'ALABAMA', 'TEXAS'}),
#  frozenset({'MISSOURI', 'NEWYORK'}),
#  frozenset({'MISSOURI', 'WIRELINES'}),
#  frozenset({'MISSOURI', 'PENSELVANIYA'}),
#  frozenset({'ALABAMA', 'MISSOURI'}),
#  frozenset({'NEWYORK', 'WIRELINES'}),
#  frozenset({'NEWYORK', 'PENSELVANIYA'}),
#  frozenset({'ALABAMA', 'NEWYORK'}),
#  frozenset({'PENSELVANIYA', 'WIRELINES'}),
#  frozenset({'ALABAMA', 'WIRELINES'}),
#  frozenset({'ALABAMA', 'PENSELVANIYA'})]

# %% [markdown]
# # Mining association rules from frequent item sets

# %% [raw]
# Association rules are usually required to satisfy a user-specified minimum support and a user-specified minimum confidence at the same time. Association rule generation is usually split up into two separate steps:
#
# A minimum support threshold is applied to find all frequent itemsets in a database.
# A minimum confidence constraint is applied to these frequent itemsets in order to form rules.

# %% [raw]
# To find association rules, we first start with a frequent itemset. We know this set of items is unique, but we want to see if there is anything else we can get out of these items. One item or one set of items can imply another item.
#
# generateRules(), is the main command, which calls the other two.
#
# The generateRules() function takes three inputs: a list of frequent itemsets, a dictionary of support data for those itemsets, and a minimum confidence threshold. It’s going to generate a list of rules with confidence values that we can sort through later.

# %%
def generateRules(L, supportData, minConf=0.7):  #supportData is a dict coming from scanD
    bigRuleList = []
    for i in range(1, len(L)):#only get the sets with two or more items
        for freqSet in L[i]:
            H1 = [frozenset([item]) for item in freqSet]
            if (i > 1):
                rulesFromConseq(freqSet, H1, supportData, bigRuleList, minConf)
            else:
                calcConf(freqSet, H1, supportData, bigRuleList, minConf)
    return bigRuleList

# %% [raw]
# calcConf() calculates the confidence of the rule and then find out the which rules meet the minimum confidence.

# %%
def calcConf(freqSet, H, supportData, brl, minConf=0.7):
    prunedH = [] #create new list to return
    for conseq in H:
        conf = supportData[freqSet]/supportData[freqSet-conseq] #calc confidence
        if conf >= minConf: 
            print (freqSet-conseq,'-->',conseq,'conf:',conf)
            brl.append((freqSet-conseq, conseq, conf))
            prunedH.append(conseq)
    return prunedH

# %% [raw]
# rulesFromConseq() generates more association rules from our initial dataset. This takes a frequent itemset and H, which is a list of items that could be on the right-hand side of a rule.

# %%
def rulesFromConseq(freqSet, H, supportData, brl, minConf=0.7):
    m = len(H[0])
    if (len(freqSet) > (m + 1)): #try further merging
        Hmp1 = aprioriGen(H, m+1)#create Hm+1 new candidates
        Hmp1 = calcConf(freqSet, Hmp1, supportData, brl, minConf)
        if (len(Hmp1) > 1):    #need at least two sets to merge
            rulesFromConseq(freqSet, Hmp1, supportData, brl, minConf)

# %%
L,suppData= apriori(a,minSupport=0.1)

# %%
rules= generateRules(L,suppData, minConf=0.1)
# Out:
# (frozenset(['NEWYORK']), '-->', frozenset(['WIRELESS']), 'conf:', 0.393103448275862)
# (frozenset(['WIRELESS']), '-->', frozenset(['NEWYORK']), 'conf:', 0.32947976878612717)

# %% [markdown]
# I have taken only a small part of the dataset for which I have analyzed the above results.
#
# The above rules confidently says that in NEWYORK city wirless is more and there is more confidence to install more wireless  over there and vice versa.

# %% [raw]
# Citation:
#
# [1].vaish, piush. “Apriori Algorithm (Python 3.0).” A Data Analyst, Piush.vaish, 7 Aug. 2016, adataanalyst.com/machine-learning/apriori-algorithm-python-3-0/.
